# %% [markdown]
# Scikit: Libreria para aprendizaje supervisado y no supervisado
#
# Todos lo algoritmos incluidos
# Versatil
# Facil uso

# %% [markdown]
# # **Prediccion de datos**
#
# Dar un historico de datos, para aprender como le va y en base a eso el modelo determinara un resultado futuro

# %% [markdown]
# # **Sobreajuste y Subajuste**
#
# Sobre: Entender solo un caso, se debe ser plural en los datos (overfitting)
# Sub: Fallara por cantidad insuficiente de datos
