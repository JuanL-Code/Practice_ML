# %% [markdown]
# Pandas: Libreria para el manejo de datos muy eficiente.
#
# Tipos de datos: Series (1D) y DataFrames(2D) Panels(3D)

# %%
import pandas as pd

# %% [markdown]
# # Estructura de datos tipo series
#
# Similar a diccionarios

# %%
series = pd.Series([5,10,15,20,25])

# %%
series
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 20

# %%
cad = pd.Series(["p","l","a","t","z","i"])

# %%
cad
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object

# %% [markdown]
# # Estructura de dato tipo DataFrame

# %%
lst = ["Hola", "Mundo", "Robotico"]
df = pd.DataFrame(lst)
print(df)
# Out:
#           0
# 0      Hola
# 1     Mundo
# 2  Robotico

# %%
data = {"Nombre" : ["Juan", "Ana", "Jose", "Arturo"], 
        "Edad" : [25,18,23,27], 
        "Pais": ["Mexico", "Colombia", "Brasil", "Peru"]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad      Pais
# 0    Juan    25    Mexico
# 1     Ana    18  Colombia
# 2    Jose    23    Brasil
# 3  Arturo    27      Peru

# %%
print (df[["Nombre", "Pais"]])
# Out:
#    Nombre      Pais
# 0    Juan    Mexico
# 1     Ana  Colombia
# 2    Jose    Brasil
# 3  Arturo      Peru

# %%
data = pd.read_csv("canciones-2018.csv")
#Ya que es grande solo llamamos a los 5 primeros elementos
data.head(5)
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#
# [5 rows x 16 columns]

# %%
artistas = data.artists
artistas[5]
# Out:
# 'Post Malone'

# %%
#Informacion de solo una fila
info = data.iloc[15]
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                        8
# loudness                              -4.946
# mode                                       1
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                           232187
# time_signature                             4
# Name: 15, dtype: object

# %%
#Si solo deseo ver el final del archivo

data.tail()
# Out:
#                        id  ... time_signature
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
#
# [5 rows x 16 columns]

# %%
#Amplitud del archivo
data.shape
# Out:
# (100, 16)

# %%
#Ver solo columnas
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
data["tempo"].describe()
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
#Ordenar
data.sort_index(axis = 0, ascending=False)
# Out:
#                        id  ... time_signature
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# ..                    ...  ...            ...
# 4   2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
# 3   3swc6WTsr7rl9DqQKQA55  ...            4.0
# 2   0e7ipj03S05BNilyu5bRz  ...            4.0
# 1   3ee8Jmje8o58CHK66QrVC  ...            4.0
# 0   6DCZcSspjsKoFjzjrWoCd  ...            4.0
#
# [100 rows x 16 columns]

# %% [markdown]
# # Ordenar 3 columnas de manera ascendente

# %%
subset = data[["name", "tempo", "duration_ms"]]
subset.sort_values(by="tempo", axis=0, ascending =True)
# Out:
#                              name    tempo  duration_ms
# 38                        changes   64.934     121887.0
# 1                            SAD!   75.023     166606.0
# 0                      God's Plan   77.169     198973.0
# 71                  Feel It Still   79.028     163253.0
# 78                       Criminal   79.997     232550.0
# ..                            ...      ...          ...
# 98    Dusk Till Dawn - Radio Edit  180.043     239000.0
# 17                              X  180.073     173628.0
# 81                       Stir Fry  181.967     190288.0
# 93                     This Is Me  191.702     234707.0
# 85  Coraz?n (feat. Nego do Borel)  198.075     184720.0
#
# [100 rows x 3 columns]
